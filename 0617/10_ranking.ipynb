# %%
from IPython.display import Image
Image('./ranking.png', width='900')

# %%
# 선택정렬의 반복 알고리즘을 이용해 내림차순(큰 점수가 1등) 석차를 계산하는 프로그램
score = [70, 100, 80, 100, 90]
# 석차를 기억할 리스트를 만든다.
rank = [1 for i in range(len(score))]
# print(rank)

for i in range(len(score) - 1):
    for j in range(i + 1, len(score)):
        # i번째 점수가 크면 j번째 석차를 1증가시키고 j번째 점수가 크면 i번째 석차를 1증가시킨다.
        # 부등호 방향을 반대로 변경하면 오름차순(작은 점수가 1등) 석차가 계산된다.
        if score[i] > score[j]:
            rank[j] += 1
        elif score[i] < score[j]:
            rank[i] += 1
            
# 점수와 석차를 출력하고 10점 단위로 별점을 부여한다.
for i in range(len(score)):
    print('{0:3d}점은 {1}등 입니다.'.format(score[i], rank[i]), end=' ')
    print('★' * (score[i] // 10))
# Out:
#  70점은 5등 입니다. ★★★★★★★
# 100점은 1등 입니다. ★★★★★★★★★★
#  80점은 4등 입니다. ★★★★★★★★
# 100점은 1등 입니다. ★★★★★★★★★★
#  90점은 3등 입니다. ★★★★★★★★★
